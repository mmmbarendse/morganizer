# %%
import requests

url = "https://api.themoviedb.org/3/account/20956128"

headers = {
    "accept" : "application/json",
    "Authorization" : "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhOGE1ZWUxM2M5NWFlZjY3ZTk3NTdiOGY0NmJjZTdhMCIsInN1YiI6IjY1YjhmOWUyMmYyNjZiMDE2NGUxMDU0MSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2y-5JQMzCNuWqpePIcAVGWrA5nwdvZJwH8eZhlfK1sg"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"avatar":{"gravatar":{"hash":"54e29795f341b2c92a93006f445c788b"},"tmdb":{"avatar_path":null}},"id":20956128,"iso_639_1":"en","iso_3166_1":"AT","name":"","include_adult":false,"username":"n0rm1e"}

# %%
API_TOKEN = "a8a5ee13c95aef67e9757b8f46bce7a0"

url = "https://api.themoviedb.org/3/search/movie"

headers = {
    "Content-Type" : "application/json;charset=utf-8",
    "Accept" : "application/json", 
    "Connection" : "close"
}

params = {
    "api_key" : API_TOKEN,
    "query" : "The Matrix"
}

# %%
response = requests.request(method="GET", url=url, params=params, headers=headers)

response.text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/ncEsesgOJDNrTUED89hYbA117wo.jpg","genre_ids":[28,878],"id":603,"original_language":"en","original_title":"The Matrix","overview":"Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.","popularity":70.662,"poster_path":"/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg","release_date":"1999-03-31","title":"The Matrix","video":false,"vote_average":8.212,"vote_count":24405},{"adult":false,"backdrop_path":"/eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg","genre_ids":[878,28,12],"id":624860,"original_language":"en","original_title":"The Matrix Resurrections","overview":"Plagued by strange memories, Neo\'s life takes an unexpected turn when he finds himself back inside the Matrix.","popularity":56.867,"poster_path":"/8c4a8kE7PizaGQQnditMmI1xbRp.jpg","release_date":"2021-12-16","title":"The Matrix Resurrections","video":false,"vote_average":
# ...

# %%
import pandas as pd

pd.DataFrame(response.json()['results']).head()
# Out:
#    adult                     backdrop_path          genre_ids      id  \
# 0  False  /ncEsesgOJDNrTUED89hYbA117wo.jpg          [28, 878]     603
# 1  False  /eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg      [878, 28, 12]  624860
# 2  False  /pxK1iK6anS6erGg4QePmMKbB1E7.jpg  [12, 28, 53, 878]     604
# 3  False  /533xAMhhVyjTy8hwMUFEt5TuDfR.jpg  [12, 28, 53, 878]     605
# 4  False  /lBdXACywnLwKUZmZkZ87djDQBeV.jpg               [99]   14543
#
#   original_language            original_title  \
# 0                en                The Matrix
# 1                en  The Matrix Resurrections
# 2                en       The Matrix Reloaded
# 3                en    The Matrix Revolutions
# 4                en      The Matrix Revisited
#
#                                             overview  popularity  \
# 0  Set in the 22nd century, The Matrix tells the ...      70.662
# 1  Plagued by strange memories, Neo's life takes ...      56.867
# ...

# %%
import pathlib

cwd = pathlib.Path().resolve()
path_to_read_from = cwd.parent.joinpath("data").joinpath("local_movies_meta.csv")
local_movies_df = pd.read_csv(path_to_read_from)

local_movies_df
# Out:
#     Unnamed: 0                                               name  year  \
# 0            0  Rye.Lane.2023.1080p.WEBRip.1400MB.DD5.1.x264-G...  2023
# 1            1  The Sure Thing (1985) [1080p] [BluRay] [5.1] [...  1985
# 2            2   Life As A House (2001) [1080p] [WEBRip] [YTS.MX]  2001
# 3            3  Ivan The Terrible, Part II (1958) [BluRay] [10...  1958
# 4            4    Anatomy Of A Fall (2023) 1080p BluRay 5.1-WORLD  2023
# 5            5  Ivan The Terrible, Part I (1944) [BluRay] [108...  1944
# 6            6            El Sur (1983) [BluRay] [1080p] [YTS.AM]  1983
# 7            7  Predestination (2014) (1080p BluRay x265 10bit...  2014
# 8            8  Asteroid.City.2023.REPACK.1080p.WEBRip.1400MB....  2023
# 9            9  The.Holdovers.2023.1080p.WEBRip.1600MB.DD5.1.x...  2023
# 10          10  The.Killer.2023.1080p.NF.WEBRip.1400MB.DD5.1.x...  2023
# 11          11  No.Country.for.Old.Men.2007.1080p.BluRay.H264....  2007
# ...

# %%
local_movies_df.testsplit
# Out:
# 0                                      Rye Lane
# 1                                The Sure Thing
# 2                               Life As A House
# 3                    Ivan The Terrible, Part II
# 4                             Anatomy Of A Fall
# 5                     Ivan The Terrible, Part I
# 6                                        El Sur
# 7                                Predestination
# 8                                 Asteroid City
# 9                                 The Holdovers
# 10                                   The Killer
# 11                       No Country for Old Men
# 12                                 Hit The Road
# 13                     The Man with the Answers
# 14                              Young Beautiful
# 15                                 Che Part One
# 16                                 May December
# 17                                Infinity Pool
# 18                             The Last Samurai
# 19                                    Shithouse
# ...

# %%
search_string = local_movies_df.loc[40, "testsplit"]
print(search_string)

new_ss = {
    'query' : search_string
}

params.update(new_ss)

response = requests.get(url=url, params=params, headers=headers)
response.json()['total_results']
# Out:
# Oppenheimer
# 22

# %%
df_results = pd.DataFrame(response.json()['results']).head()
df_results.release_date = pd.to_datetime(df_results.release_date)
df_results['release_year'] = df_results.release_date.dt.year
df_results
# Out:
#    adult                     backdrop_path    genre_ids       id  \
# 0  False  /fm6KqXpk3M2HVveHwCrBSSBaO0V.jpg     [18, 36]   872585
# 1  False                              None         [99]   384470
# 2  False                              None  [18, 10770]  1156529
# 3  False                              None         [99]  1152711
# 4  False  /lv606WMZ9iZpIo6o3yeIVDAEBOl.jpg     [99, 36]  1149947
#
#   original_language                                 original_title  \
# 0                en                                    Oppenheimer
# 1                es                 La balada del Oppenheimer Park
# 2                sh                              Slučaj Openhajmer
# 3                en         Inside Christopher Nolan's Oppenheimer
# 4                en  To End All War: Oppenheimer & the Atomic Bomb
#
#                                             overview  popularity  \
# 0  The story of J. Robert Oppenheimer's role in t...     463.169
# ...
